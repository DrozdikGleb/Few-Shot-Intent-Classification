# %%
import pandas as pd
import numpy as np
import random

from deap import base
from deap import creator
from deap import tools

# %%
def read_msg_and_embs_and_lbls(path):
    msgs = []
    labels = []
    with open(f"{path}/seq.in", 'r') as seq_file:
        for line in seq_file:
            msgs.append(line.strip())
    
    with open(f"{path}/label", 'r') as label_file:
        for line in label_file:
            labels.append(line.strip())
    
    embs = np.load(f"{path}/embs.npy")
    
    tuples = []
    
    for i in range(len(msgs)):
        tuples.append((msgs[i], embs[i], labels[i]))
    
    tuples = sorted(tuples, key=lambda x: x[2])
    new_msgs, new_embs, new_labels = [], [], []
    
    for i in range(len(msgs)):
        new_msgs.append(tuples[i][0])
        new_embs.append(tuples[i][1])
        new_labels.append(tuples[i][2])
    
    return new_msgs, new_embs, new_labels

# %%
def read_augs_to_pandas():
    true_data = read_msg_and_embs_and_lbls('./aug_data/data/banking77/train_10/')
    back_trans = read_msg_and_embs_and_lbls('./aug_data/data/back_translation/')
    context_replacement = read_msg_and_embs_and_lbls('./aug_data/data/contextual_replacement/')
    glove_word_replace = read_msg_and_embs_and_lbls('./aug_data/data/glove_word_replace/')
    gpt2_msgs = read_msg_and_embs_and_lbls('./aug_data/data/gpt2_msgs/')
    random_delete = read_msg_and_embs_and_lbls('./aug_data/data/random_delete/')
    random_swap = read_msg_and_embs_and_lbls('./aug_data/data/random_swap/')
    synonym_replace = read_msg_and_embs_and_lbls('./aug_data/data/synonym_replace/')
    
    df = pd.DataFrame({
        "lbl": true_data[2],
        "true_msg": true_data[0],
        "back_trans_msg": back_trans[0],
        "context_replacement_msg": context_replacement[0],
        "glove_word_replace_msg": glove_word_replace[0],
        "gpt2_msgs_msg": gpt2_msgs[0],
        "random_delete_msg": random_delete[0],
        "random_swap_msg": random_swap[0],
        "synonym_replace_msg": synonym_replace[0],
        "true_embs": true_data[1],
        "back_trans_embs": back_trans[1],
        "context_replacement_embs": context_replacement[1],
        "glove_word_replace_embs": glove_word_replace[1],
        "gpt2_msgs_embs": gpt2_msgs[1],
        "random_delete_embs": random_delete[1],
        "random_swap_embs": random_swap[1],
        "synonym_replace_embs": synonym_replace[1],
    })
    
    return df

# %%
df = read_augs_to_pandas()

# %%
# df.head()

# %%
for i, val in enumerate(df.columns):
    print(i, val)
# Out:
# 0 lbl
# 1 true_msg
# 2 back_trans_msg
# 3 context_replacement_msg
# 4 glove_word_replace_msg
# 5 gpt2_msgs_msg
# 6 random_delete_msg
# 7 random_swap_msg
# 8 synonym_replace_msg
# 9 true_embs
# 10 back_trans_embs
# 11 context_replacement_embs
# 12 glove_word_replace_embs
# 13 gpt2_msgs_embs
# 14 random_delete_embs
# 15 random_swap_embs
# 16 synonym_replace_embs

# %%
def n_per_aug_method():
    return random.choices( range(1, 10), k = 7)

# %%
from sklearn.metrics import silhouette_score

# %%
print(random.randint(0, 9))
# Out:
# 7

# %%
def evaluate(individual):
    individual = individual[0]
    embs = []
    labels = []
#     print("HUI")
    for index, row in df.iterrows():
        embs.append(row['true_embs'])
        labels.append(row[0])
        for ind, el in enumerate(individual):
            rand_int = random.randint(0, 9)
            if rand_int < el:
                embs.append(row[10 + ind])
                labels.append(row[0])
    return -1 * silhouette_score(embs, labels),

# %%
# this is the setup of the deap library: registering the different function into the toolbox
creator.create("FitnessMin", base.Fitness, weights=(-1.0,))
creator.create("Individual", list, fitness=creator.FitnessMin)

toolbox = base.Toolbox()

toolbox.register("n_per_aug_method", n_per_aug_method)

toolbox.register("individual", tools.initRepeat, creator.Individual, toolbox.n_per_aug_method, n=1)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("evaluate", evaluate)
toolbox.register("mate", tools.cxTwoPoint)
toolbox.register("mutate", tools.mutUniformInt, low=1, up=10, indpb=0.1)
toolbox.register("select", tools.selTournament, tournsize=3)
# Out:
# /home/gdrozdov/anaconda3/envs/diploma/lib/python3.7/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)
# /home/gdrozdov/anaconda3/envs/diploma/lib/python3.7/site-packages/deap/creator.py:141: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   RuntimeWarning)

# %%
toolbox.population(n=10)
# Out:
# [[[2, 5, 9, 4, 2, 3, 7]],
#  [[3, 8, 1, 5, 4, 4, 9]],
#  [[4, 9, 9, 2, 3, 5, 9]],
#  [[6, 2, 5, 3, 9, 1, 9]],
#  [[2, 6, 8, 6, 2, 7, 7]],
#  [[3, 9, 8, 8, 4, 4, 5]],
#  [[8, 3, 2, 8, 6, 8, 7]],
#  [[9, 7, 1, 2, 3, 1, 8]],
#  [[9, 1, 8, 9, 5, 3, 1]],
#  [[5, 6, 1, 4, 5, 7, 2]]]

# %%
def main():
    pop = toolbox.population(n=50)

    fitnesses = list(map(toolbox.evaluate, pop))
    for ind, fit in zip(pop, fitnesses):
        ind.fitness.values = fit


    CXPB, MUTPB = 0.5, 0.2

    fits = [ind.fitness.values[0] for ind in pop]

    g = 0

    while g < 200:
        
        g = g + 1
        print("-- Generation %i --" % g)

        offspring = toolbox.select(pop, len(pop))
        offspring = list(map(toolbox.clone, offspring))

        for child1, child2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < CXPB:
                toolbox.mate(child1[0], child2[0])
                del child1.fitness.values
                del child2.fitness.values

        for mutant in offspring:
            if random.random() < MUTPB:
                toolbox.mutate(mutant[0])
                del mutant.fitness.values

        invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
        fitnesses = map(toolbox.evaluate, invalid_ind)
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit
            
        pop[:] = offspring

        fits = [ind.fitness.values[0] for ind in pop]
        
        length = len(pop)
        mean = sum(fits) / length
        sum2 = sum(x*x for x in fits)
        std = abs(sum2 / length - mean**2)**0.5
        
        cur_best = pop[np.argmin([toolbox.evaluate(x) for x in pop])]
        print(cur_best)
        #print(min(fits), max(fits), mean, std)
    
    best = pop[np.argmin([toolbox.evaluate(x) for x in pop])]
    return best

# %%
#todo попробовать без true embs

# %%
best_solution = main()
# Out:
# -- Generation 1 --
# [[9, 0, 1, 1, 3, 4, 0]]
# -- Generation 2 --
# [[9, 0, 1, 1, 0, 9, 0]]
# -- Generation 3 --
# [[4, 0, 1, 1, 0, 9, 1]]
# -- Generation 4 --
# [[2, 0, 1, 1, 0, 9, 0]]
# -- Generation 5 --
# [[9, 0, 1, 1, 0, 9, 0]]
# -- Generation 6 --
# [[2, 0, 1, 1, 0, 9, 0]]
# -- Generation 7 --
# [[4, 0, 1, 1, 0, 9, 0]]
# -- Generation 8 --
# [[4, 0, 1, 1, 0, 9, 0]]
# -- Generation 9 --
# [[2, 0, 1, 1, 0, 9, 0]]
# -- Generation 10 --
# [[2, 0, 1, 1, 0, 9, 0]]
# -- Generation 11 --
# [[2, 0, 1, 1, 0, 9, 0]]
# -- Generation 12 --
# [[4, 0, 1, 1, 0, 9, 0]]
# -- Generation 13 --
# [[2, 0, 1, 1, 0, 9, 0]]
# -- Generation 14 --
# [[2, 0, 1, 1, 0, 0, 0]]
# -- Generation 15 --
# [[2, 0, 1, 1, 0, 9, 0]]
# -- Generation 16 --
# [[2, 0, 1, 1, 0, 9, 0]]
# -- Generation 17 --
# [[2, 0, 1, 1, 0, 9, 0]]
# -- Generation 18 --
# [[2, 0, 1, 1, 0, 9, 0]]
# -- Generation 19 --
# [[2, 0, 1, 1, 0, 9, 0]]
# -- Generation 20 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 21 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 22 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 23 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 24 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 25 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 26 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 27 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 28 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 29 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 30 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 31 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 32 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 33 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 34 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 35 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 36 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 37 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 38 --
# [[2, 0, 1, 0, 0, 0, 0]]
# -- Generation 39 --
# [[2, 0, 1, 0, 0, 0, 0]]
# -- Generation 40 --
# [[2, 0, 1, 0, 0, 0, 0]]
# -- Generation 41 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 42 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 43 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 44 --
# [[2, 0, 1, 0, 0, 0, 0]]
# -- Generation 45 --
# [[2, 0, 1, 0, 0, 0, 0]]
# -- Generation 46 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 47 --
# [[2, 0, 1, 0, 0, 3, 0]]
# -- Generation 48 --
# [[2, 0, 1, 0, 0, 0, 0]]
# -- Generation 49 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 50 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 51 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 52 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 53 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 54 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 55 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 56 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 57 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 58 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 59 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 60 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 61 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 62 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 63 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 64 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 65 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 66 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 67 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 68 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 69 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 70 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 71 --
# [[2, 0, 0, 0, 0, 0, 0]]
# -- Generation 72 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 73 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 74 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 75 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 76 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 77 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 78 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 79 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 80 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 81 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 82 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 83 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 84 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 85 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 86 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 87 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 88 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 89 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 90 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 91 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 92 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 93 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 94 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 95 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 96 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 97 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 98 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 99 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 100 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 101 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 102 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 103 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 104 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 105 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 106 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 107 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 108 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 109 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 110 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 111 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 112 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 113 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 114 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 115 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 116 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 117 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 118 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 119 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 120 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 121 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 122 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 123 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 124 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 125 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 126 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 127 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 128 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 129 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 130 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 131 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 132 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 133 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 134 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 135 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 136 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 137 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 138 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 139 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 140 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 141 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 142 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 143 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 144 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 145 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 146 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 147 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 148 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 149 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 150 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 151 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 152 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 153 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 154 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 155 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 156 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 157 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 158 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 159 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 160 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 161 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 162 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 163 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 164 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 165 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 166 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 167 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 168 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 169 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 170 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 171 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 172 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 173 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 174 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 175 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 176 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 177 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 178 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 179 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 180 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 181 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 182 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 183 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 184 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 185 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 186 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 187 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 188 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 189 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 190 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 191 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 192 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 193 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 194 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 195 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 196 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 197 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 198 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 199 --
# [[0, 0, 0, 0, 0, 0, 0]]
# -- Generation 200 --
# [[0, 0, 0, 0, 0, 0, 0]]

# %%
best_solution = main()
# Out:
# -- Generation 1 --
# [[3, 2, 1, 1, 5, 5, 1]]
# -- Generation 2 --
# [[3, 4, 1, 1, 1, 8, 1]]
# -- Generation 3 --
# [[7, 1, 1, 1, 1, 8, 6]]
# -- Generation 4 --
# [[7, 1, 1, 1, 1, 8, 1]]
# -- Generation 5 --
# [[7, 1, 1, 1, 1, 8, 1]]
# -- Generation 6 --
# [[7, 1, 1, 1, 1, 8, 1]]
# -- Generation 7 --
# [[7, 1, 1, 1, 1, 8, 1]]
# -- Generation 8 --
# [[3, 1, 1, 1, 1, 8, 1]]
# -- Generation 9 --
# [[7, 1, 1, 1, 1, 8, 1]]
# -- Generation 10 --
# [[7, 1, 1, 1, 1, 8, 1]]
# -- Generation 11 --
# [[7, 1, 1, 1, 1, 8, 1]]
# -- Generation 12 --
# [[7, 1, 1, 1, 1, 8, 1]]
# -- Generation 13 --
# [[7, 1, 1, 1, 1, 8, 1]]
# -- Generation 14 --
# [[7, 1, 1, 1, 1, 8, 1]]
# -- Generation 15 --
# [[7, 1, 1, 1, 1, 8, 1]]
# -- Generation 16 --
# [[7, 1, 1, 1, 1, 8, 1]]
# -- Generation 17 --
# [[7, 1, 1, 1, 1, 8, 1]]
# -- Generation 18 --
# [[7, 1, 1, 1, 1, 8, 1]]
# -- Generation 19 --
# [[7, 1, 1, 1, 1, 8, 1]]
# -- Generation 20 --
# [[7, 1, 1, 1, 1, 8, 1]]
# -- Generation 21 --
# [[7, 1, 1, 1, 1, 8, 1]]
# -- Generation 22 --
# [[7, 1, 1, 1, 1, 8, 1]]
# -- Generation 23 --
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3166/2118291220.py in <module>
# ----> 1 best_solution = main()
#
# /tmp/ipykernel_3166/3621098017.py in main()
#      47         invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
#      48         fitnesses = map(toolbox.evaluate, invalid_ind)
# ---> 49         for ind, fit in zip(invalid_ind, fitnesses):
#      50             ind.fitness.values = fit
#      51
#
# /tmp/ipykernel_3166/104976631.py in evaluate(individual)
#       4     labels = []
#       5 #     print("HUI")
# ----> 6     for index, row in df.iterrows():
#       7         embs.append(row['true_embs'])
#       8         labels.append(row[0])
#
# ~/anaconda3/envs/diploma/lib/python3.7/site-packages/pandas/core/frame.py in iterrows(self)
#    1261         klass = self._constructor_sliced
#    1262         for k, v in zip(self.index, self.values):
# -> 1263             s = klass(v, index=columns, name=k)
#    1264             yield k, s
#    1265
#
# ~/anaconda3/envs/diploma/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     441                 manager = get_option("mode.data_manager")
#     442                 if manager == "block":
# --> 443                     data = SingleBlockManager.from_array(data, index)
#     444                 elif manager == "array":
#     445                     data = SingleArrayManager.from_array(data, index)
#
# ~/anaconda3/envs/diploma/lib/python3.7/site-packages/pandas/core/internals/managers.py in from_array(cls, array, index)
#    1572         Constructor for if we have an array that is not yet a Block.
#    1573         """
# -> 1574         block = new_block(array, placement=slice(0, len(index)), ndim=1)
#    1575         return cls(block, index)
#    1576
#
# ~/anaconda3/envs/diploma/lib/python3.7/site-packages/pandas/core/internals/blocks.py in new_block(values, placement, ndim, klass)
#    1940         klass = get_block_type(values, values.dtype)
#    1941
# -> 1942     values = maybe_coerce_values(values)
#    1943     return klass(values, ndim=ndim, placement=placement)
#    1944
#
# ~/anaconda3/envs/diploma/lib/python3.7/site-packages/pandas/core/internals/blocks.py in maybe_coerce_values(values)
#    1873     # Note: the only test that needs extract_array here is one where we
#    1874     #  pass PandasDtype to Series.astype, then need to extract PandasArray here.
# -> 1875     values = extract_array(values, extract_numpy=True)
#    1876
#    1877     if isinstance(values, np.ndarray):
#
# ~/anaconda3/envs/diploma/lib/python3.7/site-packages/pandas/core/construction.py in extract_array(obj, extract_numpy, extract_range)
#     415     array([1, 2, 3])
#     416     """
# --> 417     if isinstance(obj, (ABCIndex, ABCSeries)):
#     418         if isinstance(obj, ABCRangeIndex):
#     419             if extract_range:
#
# ~/anaconda3/envs/diploma/lib/python3.7/site-packages/pandas/core/dtypes/generic.py in _check(cls, inst)
#      41     # https://github.com/python/mypy/issues/1006
#      42     # error: 'classmethod' used with a non-method
# ---> 43     @classmethod  # type: ignore[misc]
#      44     def _check(cls, inst) -> bool:
#      45         return getattr(inst, attr, "_typ") in comp
#
# KeyboardInterrupt:
